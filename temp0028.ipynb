# %%
# %run ./temp0028.py
df
# Out:
# <style  type="text/css" >
#     #T_41c5fb66_ab55_11ea_b60c_00e04caa3030row0_col2 {
#             background-color:  yellow;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_41c5fb66_ab55_11ea_b60c_00e04caa3030row0_col3 {
#             background-color:  yellow;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_41c5fb66_ab55_11ea_b60c_00e04caa3030row0_col4 {
#             background-color:  ;
#             background-color:  lightgreen;
#             background-color:  ;
#             background-color:  ;
#         }    #T_41c5fb66_ab55_11ea_b60c_00e04caa3030row0_col5 {
#             background-color:  lightgreen;
#             background-color:  ;
#         }    #T_41c5fb66_ab55_11ea_b60c_00e04caa3030row0_col6 {
#             background-color:  ;
# ...
