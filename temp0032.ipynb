# %%
# %run ./temp0032.py
df
# Out:
# <style  type="text/css" >
#     #T_ae011d12_ab55_11ea_8f2c_00e04caa3030row0_col2 {
#             background-color:  yellow;
#             background-color:  lightgreen;
#             background-color:  green;
#             background-color:  ;
#             background-color:  ;
#         }    #T_ae011d12_ab55_11ea_8f2c_00e04caa3030row0_col3 {
#             background-color:  yellow;
#             background-color:  lightgreen;
#             background-color:  green;
#             background-color:  ;
#         }    #T_ae011d12_ab55_11ea_8f2c_00e04caa3030row0_col4 {
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_ae011d12_ab55_11ea_8f2c_00e04caa3030row0_col5 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_ae011d12_ab55_11ea_8f2c_00e04caa3030row0_col6 {
#             background-color:  ;
# ...
