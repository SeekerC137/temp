# %%
# %run ./temp0013.py
df
# Out:
# <style  type="text/css" >
#     #T_1db2976c_ab53_11ea_9395_00e04caa3030row0_col2 {
#             background-color:  yellow;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_1db2976c_ab53_11ea_9395_00e04caa3030row0_col3 {
#             background-color:  yellow;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_1db2976c_ab53_11ea_9395_00e04caa3030row0_col4 {
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_1db2976c_ab53_11ea_9395_00e04caa3030row0_col5 {
#             background-color:  lightgreen;
#             background-color:  ;
#         }    #T_1db2976c_ab53_11ea_9395_00e04caa3030row0_col6 {
#             background-color:  ;
#         }    #T_1db2976c_ab53_11ea_9395_00e04caa3030row1_col2 {
# ...
