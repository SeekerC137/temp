# %%
# %run ./temp0026.py
# ОБЯЗАТЕЛЬНО нажмите кнопку "Run" для актуализации данных!
# Затем нажмите "Out[1]" чтобы развернуть таблицу.
df
# Out:
# <style  type="text/css" >
#     #T_f61c04ec_ab54_11ea_b422_00e04caa3030row0_col2 {
#             background-color:  yellow;
#             background-color:  lightgreen;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_f61c04ec_ab54_11ea_b422_00e04caa3030row0_col3 {
#             background-color:  yellow;
#             background-color:  lightgreen;
#             background-color:  green;
#             background-color:  ;
#         }    #T_f61c04ec_ab54_11ea_b422_00e04caa3030row0_col4 {
#             background-color:  ;
#             background-color:  lightgreen;
#             background-color:  ;
#             background-color:  ;
#         }    #T_f61c04ec_ab54_11ea_b422_00e04caa3030row0_col5 {
#             background-color:  lightgreen;
#             background-color:  ;
#         }    #T_f61c04ec_ab54_11ea_b422_00e04caa3030row0_col6 {
#             background-color:  ;
# ...
