# %%
# %run ./temp0008.py
df
# Out:
# <style  type="text/css" >
#     #T_31eb2e76_ab52_11ea_83dc_00e04caa3030row0_col2 {
#             background-color:  yellow;
#             background-color:  lightgreen;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_31eb2e76_ab52_11ea_83dc_00e04caa3030row0_col3 {
#             background-color:  yellow;
#             background-color:  lightgreen;
#             background-color:  green;
#             background-color:  ;
#         }    #T_31eb2e76_ab52_11ea_83dc_00e04caa3030row0_col4 {
#             background-color:  ;
#             background-color:  lightgreen;
#             background-color:  ;
#             background-color:  ;
#         }    #T_31eb2e76_ab52_11ea_83dc_00e04caa3030row0_col5 {
#             background-color:  lightgreen;
#             background-color:  ;
#         }    #T_31eb2e76_ab52_11ea_83dc_00e04caa3030row0_col6 {
#             background-color:  ;
# ...
