# %%
# %run ./temp0016.py
# ОБЯЗАТЕЛЬНО нажмите кнопку "Run" для актуализации данных!
# Затем нажмите "Out[1]" чтобы развернуть таблицу.
df
# Out:
# <style  type="text/css" >
#     #T_a6589498_ab53_11ea_9abf_00e04caa3030row0_col2 {
#             background-color:  yellow;
#             background-color:  lightgreen;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_a6589498_ab53_11ea_9abf_00e04caa3030row0_col3 {
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#             background-color:  pink;
#         }    #T_a6589498_ab53_11ea_9abf_00e04caa3030row0_col4 {
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_a6589498_ab53_11ea_9abf_00e04caa3030row0_col5 {
#             background-color:  lightgreen;
#             background-color:  ;
#         }    #T_a6589498_ab53_11ea_9abf_00e04caa3030row0_col6 {
#             background-color:  ;
# ...
