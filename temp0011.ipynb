# %%
# %run ./temp0011.py
df
# Out:
# <style  type="text/css" >
#     #T_caf01f62_ab52_11ea_b5fb_00e04caa3030row0_col2 {
#             background-color:  yellow;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_caf01f62_ab52_11ea_b5fb_00e04caa3030row0_col3 {
#             background-color:  yellow;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_caf01f62_ab52_11ea_b5fb_00e04caa3030row0_col4 {
#             background-color:  ;
#             background-color:  lightgreen;
#             background-color:  ;
#             background-color:  ;
#         }    #T_caf01f62_ab52_11ea_b5fb_00e04caa3030row0_col5 {
#             background-color:  lightgreen;
#             background-color:  ;
#         }    #T_caf01f62_ab52_11ea_b5fb_00e04caa3030row0_col6 {
#             background-color:  ;
# ...
