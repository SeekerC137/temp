# %%
# %run ./temp0006.py
df
# Out:
# <style  type="text/css" >
#     #T_bf6df5a6_ab51_11ea_85ef_00e04caa3030row0_col2 {
#             background-color:  yellow;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_bf6df5a6_ab51_11ea_85ef_00e04caa3030row0_col3 {
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#             background-color:  pink;
#         }    #T_bf6df5a6_ab51_11ea_85ef_00e04caa3030row0_col4 {
#             background-color:  ;
#             background-color:  lightgreen;
#             background-color:  ;
#             background-color:  ;
#         }    #T_bf6df5a6_ab51_11ea_85ef_00e04caa3030row0_col5 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_bf6df5a6_ab51_11ea_85ef_00e04caa3030row0_col6 {
#             background-color:  lightblue;
# ...
