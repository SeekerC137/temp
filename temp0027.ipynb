# %%
# %run ./temp0027.py
# ОБЯЗАТЕЛЬНО нажмите кнопку "Run" для актуализации данных!
# Затем нажмите "Out[1]" чтобы развернуть таблицу.
df
# Out:
# <style  type="text/css" >
#     #T_073715a2_ab55_11ea_ba25_00e04caa3030row0_col2 {
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#             background-color:  pink;
#             background-color:  ;
#         }    #T_073715a2_ab55_11ea_ba25_00e04caa3030row0_col3 {
#             background-color:  yellow;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_073715a2_ab55_11ea_ba25_00e04caa3030row0_col4 {
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_073715a2_ab55_11ea_ba25_00e04caa3030row0_col5 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_073715a2_ab55_11ea_ba25_00e04caa3030row0_col6 {
#             background-color:  lightblue;
#         }    #T_073715a2_ab55_11ea_ba25_00e04caa3030row1_col2 {
# ...
