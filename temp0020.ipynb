# %%
# %run ./temp0020.py
df
# Out:
# <style  type="text/css" >
#     #T_26555ed4_ab54_11ea_aeb9_00e04caa3030row0_col2 {
#             background-color:  yellow;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#             background-color:  ;
#         }    #T_26555ed4_ab54_11ea_aeb9_00e04caa3030row0_col3 {
#             background-color:  yellow;
#             background-color:  lightgreen;
#             background-color:  green;
#             background-color:  ;
#         }    #T_26555ed4_ab54_11ea_aeb9_00e04caa3030row0_col4 {
#             background-color:  ;
#             background-color:  lightgreen;
#             background-color:  ;
#             background-color:  ;
#         }    #T_26555ed4_ab54_11ea_aeb9_00e04caa3030row0_col5 {
#             background-color:  lightgreen;
#             background-color:  ;
#         }    #T_26555ed4_ab54_11ea_aeb9_00e04caa3030row0_col6 {
#             background-color:  ;
# ...
